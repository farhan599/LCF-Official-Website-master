# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
from keras.models import load_model
from numpy import array
import warnings
warnings.filterwarnings('ignore')
from pandas._libs import index
import plotly.express as px

# %%
#loading  data 
data= pd.read_csv("C:\LCF Official Website\core\ml_notebooks\combine.csv", parse_dates=['Date'], index_col='Date')

model1  = load_model('C:\LCF Official Website\core\ml_notebooks\model2.h5')

# %% [markdown]
# # **Currently available Data**

# %%
data
fig = px.line(data , y='waterLevel',   width=1500, height=1000, title='Groundwater level of Kuchlak from 2010 to 2020' , labels=dict(index="Date"))

fig.update_xaxes(
      rangeslider_visible=True)

fig.show()

# %%
def forecast(model, batch_size, data):
  test_predictions = []
  X = data.tail(12)
  Y = X.to_numpy()
  Y = Y.reshape(1, len(X), 1)

  for i in range(batch_size):
    
    # get the prediction value for the first batch
    current_pred = model1.predict(Y)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    Y = np.append(Y[:,1:,:],[[current_pred]],axis=1)
    

    def inner_func(X):  
        new = X
        new= pd.Index(pd.date_range(start = X.index[-1], periods= batch_size, freq = "M")).strftime('%Y-%m')
        new.index=  pd.to_datetime(new)
        return new
    

  
  df1 = pd.DataFrame(test_predictions,
                          index= inner_func(X),
                          columns=['waterlevel'])
  return df1




def plot(data):
  # fig = px.line(df , y='waterlevel',   width=1500, height=1000, title=' Predicted Groundwater level of Kuchlak ' , labels=dict(index="Date"))

  # fig.update_xaxes(
  #     rangeslider_visible=True,
      
  #     )

  # return fig.show()
  batch_size = 12
  df = forecast(model1, batch_size, data)
  plt.plot("Date", "waterlevel", data=df)
  plt.show()
  plt.savefig("C\LCF Official Website\statici\mages\plot.png")



def func(data, siteID):
    well = data[siteID]
    #well= well[:102]
    well = well.tail(12)
    well = well.to_frame()
   
    return well

# %%
#batch size is actually the number of months you want to predict further

batch_size= int(input("12"))
df= forecast(model1, batch_size, data)
plot(df)
# Out:
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 38ms/step

# %% [markdown]
# # **Predictions by Site ID**

# %%
data2 = pd.read_csv("C:/LCF Official Website/core/ml_notebooks/all_wells20.csv", parse_dates=['Date'] , index_col='Date')

# %%
site= input("Enter SITE ID  : ")
df1 = func(data2, site)
batch_size= int(input("Enter batch size   : "))
df= forecast(model1, batch_size, df1)
plot(df)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '12'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\LCF Official Website\core\ml_notebooks\predict_waterlevel (1).ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/LCF%20Official%20Website/core/ml_notebooks/predict_waterlevel%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> site= input("Enter SITE ID  : ")
# ----> <a href='vscode-notebook-cell:/c%3A/LCF%20Official%20Website/core/ml_notebooks/predict_waterlevel%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> df1 = func(data2, site)
#       <a href='vscode-notebook-cell:/c%3A/LCF%20Official%20Website/core/ml_notebooks/predict_waterlevel%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> batch_size= int(input("Enter batch size   : "))
#       <a href='vscode-notebook-cell:/c%3A/LCF%20Official%20Website/core/ml_notebooks/predict_waterlevel%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> df= forecast(model1, batch_size, df1)
#
# c:\LCF Official Website\core\ml_notebooks\predict_waterlevel (1).ipynb Cell 9 in func(data, siteID)
#      <a href='vscode-notebook-cell:/c%3A/LCF%20Official%20Website/core/ml_notebooks/predict_waterlevel%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=46'>47</a> def func(data, siteID):
# ---> <a href='vscode-notebook-cell:/c%3A/LCF%20Official%20Website/core/ml_notebooks/predict_waterlevel%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=47'>48</a>     well = data[siteID]
#      <a href='vscode-notebook-cell:/c%3A/LCF%20Official%20Website/core/ml_notebooks/predict_waterlevel%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=48'>49</a>     #well= well[:102]
#      <a href='vscode-notebook-cell:/c%3A/LCF%20Official%20Website/core/ml_notebooks/predict_waterlevel%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=49'>50</a>     well = well.tail(12)
#
# File c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: '12'
